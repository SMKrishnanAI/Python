# %%
# 1. Scenario: A system checks if a user is eligible to vote based on their age.
# Logic:
# 1. Ask the user to enter their age.
# 2. Check if the age is 18 or older.
# 3. If yes, print "Eligible to vote."
# 4. Otherwise, print "Not eligible to vote."
print("Scenario: Eligiblity to vote based on age") 
print("-------------------------------------------") 
age=int(input("Please enter your age: ")) 
if age >= 18 : 
    print("Eligible to vote.") 
else: 
    print( "Not eligible to vote.")
# Out:
# Scenario: Eligiblity to vote based on age
# -------------------------------------------
# Please enter your age:  20
# Eligible to vote.

# %%
# 2. Scenario: A program processes a list of numbers and needs to find the largest value.
# Logic:
# 1.	Read the list of numbers.
# 2.	Assume the first number is the largest.
# 3.	Iterate through the list, comparing each number with the current largest value.
# 4.	If a larger number is found, update the largest value.
# 5.	Return the largest number.

def  find_large():
    print("program processes a list of numbers and find the largest:")
    print("-")
    list1= [int(x) for x in input("Enter list of numbers space separated:").split()]
    #print("list value:", list1)
    for i in range(len(list1)):
        if i==0:
            largest = list1[i]    #Assume the first number is the largest.
            continue
        currval = list1[i]
        if currval > largest:
            largest = currval
    return largest

largest_val=find_large()
print("largest value :", largest_val)
# Out:
# program processes a list of numbers and find the largest:
# -
# Enter list of numbers space separated: 12 10 13 14 99 55 16 98 22 33
# largest value : 99

# %%
# 3. Scenario: A company provides employees with a 10% bonus if their salary exceeds $50,000.
#  Logic:
# 1.	Read the employee's salary.
# 2.	If the salary is greater than $50,000, calculate a 10% bonus.
# 3.	Otherwise, set the bonus to zero.
# 4.	Return the calculated bonus amount.
print("Bonus calculation: 10% if sal > $50,000 otherwise zero")
print("-------------------------------------------------------")
print()
sal_dbase = {"Sam": 100000, "Dickson": 20000, "Ferguson" : 50000, "Helen": 25000, "Sarah" : 35000 , "Philip":55000}
print("display bonus figure for all employee's result==> (name, salary,bonus)")
print("----------------------------------------------------------------------")
sal_bonus=[(n,s, int(s * 0.10)) if s > 50000 else (n,s, 0) for n, s in sal_dbase.items()]
print(sal_bonus)
print()

print("display only employee's who received bonus: result==> (name, salary,bonus)")
print("----------------------------------------------------------------------")
sal_bonus=[(n,s, int(s * 0.10))  for n, s in sal_dbase.items()  if s > 50000 ]
print(sal_bonus)
# Out:
# Bonus calculation: 10% if sal > $50,000 otherwise zero
# -------------------------------------------------------
#
# display bonus figure for all employee's result==> (name, salary,bonus)
# ----------------------------------------------------------------------
# [('Sam', 100000, 10000), ('Dickson', 20000, 0), ('Ferguson', 50000, 0), ('Helen', 25000, 0), ('Sarah', 35000, 0), ('Philip', 55000, 5500)]
#
# display only employee's who received bonus: result==> (name, salary,bonus)
# ----------------------------------------------------------------------
# [('Sam', 100000, 10000), ('Philip', 55000, 5500)]

# %%
# 4. Scenario: A program evaluates a number to determine if it is even or odd.
#  Logic:
# 1.	Read the input number.
# 2.	Check if the number is divisible by 2.
# 3.	If yes, print "Even."
# 4.	Otherwise, print "Odd."

num1=int(input("Enter a number to find if it is even or odd: "))
if num1%2 == 0:
         print(num1, "is even number")
else:
         print(num1, "is odd number")
# Out:
# Enter a number to find if it is even or odd:  3
# 3 is odd number

# %%
# 5.	Scenario: A text-processing tool reverses a given word or sentence for formatting purposes.
#  Logic:
# 1.Read the input word or sentence.
# 2.Convert the input into a list of characters.
# 3.Reverse the order of characters.
# 4.Join the reversed characters into a string.
# 5.Return the reversed word or sentence.
Sentence=input("Enter a sentence or a word: ")
print("Original: ",Sentence)
list1=list(Sentence)
list2=list1[::-1]
result="".join(list2)
print("Reversed: ",result)
# Out:
# Enter a sentence or a word:  Alita BattleBot!
# Original:  Alita BattleBot!
# Reversed:  !toBelttaB atilA

# %%
# 6.  Scenario: A grading system determines whether a student has passed or failed based on their score.
#  Logic:
# 1.	Read the student's marks.
# 2.	If the marks are 40 or above, print "Pass."
# 3.	Otherwise, print "Fail."

Marks= {
"Math":90,
"Physics":75,
"Biology":40,
"Chemistry":80,
"English":60,
"IInd Lang":70,
"Elective.Economics":38,
"Elective.Robotics":39
}

result=[(n,v,"Pass") if v>=40 else (n,v,"Fail") for n,v in Marks.items()]
#print(result)
j=0
for i in result:
    if j == 0:
        print("('Sub', 'Marks','Pass/Fail')")
        print("----------------------------")
        j=404
    print(i)
# Out:
# ('Sub', 'Marks','Pass/Fail')
# ----------------------------
# ('Math', 90, 'Pass')
# ('Physics', 75, 'Pass')
# ('Biology', 40, 'Pass')
# ('Chemistry', 80, 'Pass')
# ('English', 60, 'Pass')
# ('IInd Lang', 70, 'Pass')
# ('Elective.Economics', 38, 'Fail')
# ('Elective.Robotics', 39, 'Fail')

# %%
# 7. Scenario: A retail store offers a 20% discount if a customer’s total order exceeds $100.
#  Logic:
# 1.	Read the total order amount.
# 2.	If the amount is more than $100, calculate a 20% discount.
# 3.	Subtract the discount from the total amount.
# 4.	Return the final amount to be paid.

shopping_bag1={
"RiceBag": 2,
"RoastedChicken":2,
"Frozen.Pizz":4,
"Facial Creame":30,
"SunScreen Lotion":2,
"Deodrant":5,
"Dior Perfume":45
}
shopping_bag2={
"RiceBag": 20,
"ShavingCreame":15,
"Roaster Cashew":40,
"Flower Bouquet":30,
"Lounge Chair":20
}

for bag in shopping_bag1, shopping_bag2 :
    shopping_bag=bag
    total=0
    for key1,value1 in shopping_bag.items():
         total += value1
    if total > 100:
        discount = total*20/100
    
        after_discount = total-discount
    
    print("Shopping items:")
    print("-"*20)
    item="Item"
    value="Amount"
    print(f"{item: <20}\t{value:>3}")
    item1="-"*20
    value1="-"*5
    print(f"{item1: <20}\t{value1:>3}")
    for item,value in shopping_bag.items():
        print(f"{item: <20}\t{value:>3}")
    print(f"{item1: <20}\t{value1:>3}")
    item="Total"
    value=total
    print(f"{item: <20}\t{value:>3}")
    if value >100:
        item="less Discount"
        value=int(-discount)
        print(f"{item: <20}\t{value:>3}")
        print(f"{item1: <20}\t{value1:>3}")
        item="After Discount"
        value=int(after_discount)
        print(f"{item: <20}\t{value:>3}")
    print(f"{item1: <20}\t{value1:>3}")
    print()
# Out:
# Shopping items:
# --------------------
# Item                	Amount
# --------------------	-----
# RiceBag             	  2
# RoastedChicken      	  2
# Frozen.Pizz         	  4
# Facial Creame       	 30
# SunScreen Lotion    	  2
# Deodrant            	  5
# Dior Perfume        	 45
# --------------------	-----
# Total               	 90
# --------------------	-----
#
# Shopping items:
# --------------------
# Item                	Amount
# --------------------	-----
# RiceBag             	 20
# ShavingCreame       	 15
# Roaster Cashew      	 40
# Flower Bouquet      	 30
# Lounge Chair        	 20
# --------------------	-----
# Total               	125
# less Discount       	-25
# --------------------	-----
# After Discount      	100
# --------------------	-----

# %%
# 8. Scenario: A banking system processes withdrawal requests and ensures the user has enough balance.
#  Logic:
# 1.	Read the account balance and withdrawal amount.
# 2.	If the withdrawal amount is less than or equal to the balance, process the withdrawal.
# 3.	Subtract the withdrawal amount from the balance and return the updated balance.
# 4.	If the withdrawal amount exceeds the balance, print "Insufficient funds."

data_list = [(101, "Alice", 500), (102, "Bob", 1200),(103, "Denise", 2000)]
print("Money Withdrawal:")
print("-----------------")
acct_id=int(input("Please enter your accountid: "))
name=input("Please enter your name: ")
amount=int(input("please enter withdrawal amount: "))

matched=0
for data1 in data_list:
    id1=data1[0]
    nm1=data1[1]
    amt1=data1[2]
    #print(id1,nm1,amt1)
    #print(acct_id,name,amount)
    #print("-------------------")
    if acct_id == id1:
        matched=1
        #print("Account Matched")
        if name == nm1:
            #print("Name Matched")
            if amount <= amt1:
                print("---------------------------------------")
                print("your current balance is: ", amt1-amount)
                print("---------------------------------------")
            else:
                print("--------------------")
                print("Insufficient Funds")
                print("---------------------")
        else:
            print("---------------------")
            print("incorrect name")
            print("---------------------")
            break

if matched == 0 :
    print("---------------------------------------------")
    print(f"Given Account: [{acct_id}] does not exists!")
    print("----------------------------------------------")
# Out:
# Money Withdrawal:
# -----------------
# Please enter your accountid:  101
# Please enter your name:  Alice
# please enter withdrawal amount:  5000
# --------------------
# Insufficient Funds
# ---------------------

# %%
# 9. Scenario: A calendar system verifies whether a given year is a leap year based on standard leap year rules.
#  Logic:
# 1.Read the input year.
# 2.If the year is divisible by 400, it is a leap year.
# 3.If the year is divisible by 100 but not by 400, it is not a leap year.
# 4.If the year is divisible by 4 but not by 100, it is a leap year.
# 5.Otherwise, it is not a leap year.

input_year=int(input("Please enter a year: "))
if input_year%400 == 0:
    print(f"Year {input_year} is a leap year")
elif input_year%100 ==0 and input_year%400 != 0 :
    print(f"Year {input_year} is not a leap year")
elif input_year%4 ==0 and input_year%100 != 0 :
    print(f"Year {input_year} is a leap year")   
else:
    print(f"Year {input_year} is not a leap year")
# Out:
# Please enter a year:  2024
# Year 2024 is a leap year

# %%
# 10. Scenario: A program filters out only even numbers from a given list.
#  Logic:
# 1.	Read the list of numbers.
# 2.	Create an empty list to store even numbers.
# 3.	Iterate through the list and check if each number is divisible by 2.
# 4.	If divisible, add the number to the new list.
# 5.	Return the list of even numbers.
input_string=input("please provide list of space separated numbers: ")
input_list=input_string.split()
print("input string of numbers space separated: ",input_string)
#print(input_list)
even_list=[int(x) for x in input_list if int(x)%2 == 0]
print("Filtered Even List from input",even_list)
# Out:
# please provide list of space separated numbers:  1 23 2 3 44 55 5 6 77 88 99
# input string of numbers space separated:  1 23 2 3 44 55 5 6 77 88 99
# Filtered Even List from input [2, 44, 6, 88]

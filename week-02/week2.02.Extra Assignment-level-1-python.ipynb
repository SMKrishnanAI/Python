# %%
# print Statement
# HOPE AI

# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
# Buy input
# Enter your Institire

# %%
institute_name = input("Enter your Institute? : ")
print("Institute Name : ",institute_name)
# Out:
# Enter your Institute? :  HOPE AI
# Institute Name :  HOPE AI

# %%
#Buy Inputs
# Enter your name: Raj
# Enter your age: 15
# Enter your school name: Guru school
# Enter your drgree: B.E CSE

# %%
name   = input("Enter your name: ")
age    = input("Enter your age: ") 
school = input("Enter your school name: ")
degree = input("Enter your drgree: ")
# Out:
# Enter your name:  Raj
# Enter your age:  15
# Enter your school name:  Guru school
# Enter your drgree:  B.E CSE

# %%
print("your name: ",name)
print("your age: ",age)
print("your school: ",school)
print("your degree: ",degree)
# Out:
# your name:  Raj
# your age:  15
# your school:  Guru school
# your degree:  B.E CSE

# %%
#Addition

# %%
a = 43
b = 34
Add = a + b
print("a   =",a)
print("b   =",b)
print("add =",Add)
# Out:
# a   = 43
# b   = 34
# add = 77

# %%
#subtraction

# %%
a = 43
b = 34
Sub = a -b
print("a   =",a)
print("b   =",b)
print("sub =",Sub)
# Out:
# a   = 43
# b   = 34
# sub = 9

# %%
#Multiplication
# a= 63
# b= 97
# Mul = 6111

# %%
a =63
b=97
mul = a*b
print("a= ", a)
print("b= ", b)
print("Mul=", mul )
# Out:
# a=  63
# b=  97
# Mul= 6111

# %%
#division
# a= 76
# b= 31
# Float Div = 2.4516129032258065

# %%
a= 76
b= 31
Div = a/b
print("a =",a )
print("b =",b)
print("Float Div =",Div )
# Out:
# a = 76
# b = 31
# Float Div = 2.4516129032258065

# %%
#Floor Division
# a= 76
# b= 31
# Floor Div = 2

# %%
a= 76
b= 31
Div = a//b
print("a =",a )
print("b =",b)
print("Floor Div =",Div )
# Out:
# a = 76
# b = 31
# Floor Div = 2

# %%
#Modulo
# a= 76
# b= 31
# Modulo = 14

# %%
a= 76
b= 31
modulo = a%b
print("a =",a )
print("b =",b)
print("Modulo =",modulo )
# Out:
# a = 76
# b = 31
# Modulo = 14

# %%
#power
# a= 4
# b= 4
# Power = 256

# %%
a= 4
b= 4
power = a**b
print("a =",a )
print("b =",b)
print("Power =",power )
# Out:
# a = 4
# b = 4
# Power = 256

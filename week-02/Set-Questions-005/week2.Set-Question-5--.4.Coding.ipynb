# %%
#1. Convert a List of Strings to Uppercase
#Question: Write a Python program to convert all strings in the list ["apple", "banana", "cherry"] to uppercase.
list1= ["apple", "banana", "cherry"]
list1=[i.upper() for i in list1 ]
print (list1)
# Out:
# ['APPLE', 'BANANA', 'CHERRY']

# %%
#2. Merge Two Dictionaries
#Question: Write a Python program to merge two dictionaries:

dict1 = {'a': 10, 'b': 20}  
dict2 = {'c': 30, 'd': 40}
# do a dict unpacking and then merge them
merged_dict={**dict1,**dict2}
print(f"{merged_dict}")
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40}

# %%
#3. Find the Intersection of Two Lists
#Question: Write a Python program to find the common elements between the two lists:

list1 = [1, 2, 3, 4, 5]  
list2 = [4, 5, 6, 7, 8]
#convert to set and find intersection
# set will eliminate duplicates

set1= set(list1)
set2= set(list2)
intersection= list ( set1 & set2 )

print(intersection)
# Out:
# [4, 5]

# %%
#4. Find the Length of Each Word in a Sentence
#Question: Write a Python program to print the length of each word in the sentence "Python is fun and powerful".

sent1="Python is fun and powerful"
list1=sent1.split(" ")
len_of_word = {}

# for word in list1:
#     if char in freq_of_char:
#         freq_of_char[word] += 1
#     else:
#         freq_of_char[word] = 1

for word in list1:
    len_of_word[word] = len(word)

print("word length:")
print("------------")
for char, count in len_of_word.items():
    print(f"'{char:8}': {count:<}")
# Out:
# word length:
# ------------
# 'Python  ': 6
# 'is      ': 2
# 'fun     ': 3
# 'and     ': 3
# 'powerful': 8

# %%
#5. Find the Sum of All Elements in a 2D List
#Question: Write a Python program to find the sum of all elements in the 2D list:


matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

total=0
for i in matrix:
    total += sum(i)
    
print("The total of matrix is: ", total)
# Out:
# The total of matrix is:  45

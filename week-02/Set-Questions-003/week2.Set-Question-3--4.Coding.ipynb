# %%
#1. Square of Numbers from 1 to 5
# Output:
# 1 4 9 16 25
for i in range(1,6):
    print(i*i, end=" ")
# Out:
# 1 4 9 16 25

# %%
#2.Swap Two Variables Without Using a Temporary Variable
#Question: Write a Python program to swap two variables a = 5 and b = 10 without using a temporary variable.

a=5
b=10
print(f"a is {a} and b is {b}")
a,b=b,a
print(f"a is {a} and b is {b}")
# Out:
# a is 5 and b is 10
# a is 10 and b is 5

# %%
#  #3.Find Even and Odd Numbers in a List
# Question: Write a Python program to separate even and odd numbers from the list [12, 17, 19, 24, 35, 40, 56].
list1=[12, 17, 19, 24, 35, 40, 56]
even = [ x for x in list1 if x%2 == 0]
odd  = [ x for x in list1 if x%2 == 1]

print(f"original list:{list1}")
print(f"Even list:{even}")
print(f"odd list:{odd}")
# Out:
# original list:[12, 17, 19, 24, 35, 40, 56]
# Even list:[12, 24, 40, 56]
# odd list:[17, 19, 35]

# %%
#4. Reverse a Number
#Question: Write a Python program to reverse the number 12345.

string1="12345"
reversed_string1=string1[::-1]

print(f"Original string: {string1} reversed string : {reversed_string1}")
# Out:
# Original string: 12345 reversed string : 54321

# %%
#5. Find the Second Largest Number in a List
#Question: Write a Python program to find the second largest number in the list [12, 45, 98, 34, 23].
list1 =  [12, 45, 98, 34, 23]
print(f"Original list : {list1}")
list1.sort()
print(f"sorted list   : {list1}")
print(f"The 2nd largest number in the list is {list1[-2]}")
# Out:
# Original list : [12, 45, 98, 34, 23]
# sorted list   : [12, 23, 34, 45, 98]
# The 2nd largest number in the list is 45

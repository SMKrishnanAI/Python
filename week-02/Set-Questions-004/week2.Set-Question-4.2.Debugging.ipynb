# %%
#1.Identify and fix the syntax error in the following code:


age = 18
if age >= 18:
    print("You are eligible to vote")

#SyntaxError: expected ':'
#sol: add colon to if statement
# Out:
# You are eligible to vote

# %%
#2.Question:
#What error will occur in the following code?


def greet():
    print("Hello, World!")

greet()

#NameError: name 'greet_user' is not defined
# solution: name error because it is trying to call some thing not present
# function is defined as greet() hence update the function call as greet() instead of greet_user()
# Out:
# Hello, World!

# %%
#3.Identify the error in this code:

name = "Alice"
age = 25
#print("My name is " + name + " and I am " + age + " years old.")
print("My name is " + name + " and I am " + str(age) + " years old.")


#TypeError: can only concatenate str (not "int") to str
# since age is int , we have to type cast age as str
# Out:
# My name is Alice and I am 25 years old.

# %%
#4.Question:
#What will happen when you run this code?

a = 10
b = 0
#b=1
result=""
try:
    result = a / b

except ZeroDivisionError :
    print ( "The divisor of the division operation cannot be zero")
    
print(result)

# Error : we get a a ZeroDivisionError: division by zero
# ensure divisor is greater than zero or
# have try and except to handle this exception
# Out:
# The divisor of the division operation cannot be zero

# %%
#5.What error will occur in the following code?

#num = int("xyz")
try:
    num = int("xyz")

except ValueError :
    print ( "since xyz cannot be converted to integer as the literal are character literals")
    
print(result)
print(num)

#ValueError: invalid literal for int() with base 10: 'xyz'
# since xyz cannot be converted to integer as the literal are alphabetic literals
# Out:
# since xyz cannot be converted to integer as the literal are character literals
#
# 5

# %%
#6.Identify the issue in this code:

data = {"name": "John", "age": 30}
#print(data["city"])
try:
    print(data["city"])

except KeyError :
    print ( "key error because the dictionary does not have any key as \"city\" ")


#KeyError: 'city'
#key error because the dictionary does not have any key by "city"
# Out:
# key error because the dictionary does not have any key as "city"

# %%
#7.What will happen when you run this code?
num = 1
while num < 5:
    print(num)
    num += 1
    
#infinite loop
# you can add a line to increment num so it does not loop infinitely
# Out:
# 1
# 2
# 3
# 4

# %%
#8.What is wrong with this code?

fruits = ("apple", "banana", "cherry")
#print(fruits[3])

try:
    print(fruits[3])

except IndexError :
    print ( "since there are only 3 items in the tuple, accessing fouth item  will raise IndexError ")

#This give IndexError, since there are not enough elements in the tuple.
# Out:
# since there are only 3 items in the tuple, accessing fouth item  will raise IndexError

# %%
#9.What will happen when you run this code?

text = "hello world"
#text.append("!")
try:
    text.append("!")

except AttributeError :
    print ( "'str' object has no attribute 'append' ")

#AttributeError 'str' object has no attribute 'append'
# Out:
# 'str' object has no attribute 'append'

# %%
#10.What is wrong with the following code?

# import randoms
# print(randoms.randint(1, 10))

import random
print(random.randint(1, 10))

# since the module name is random, correcting the name will make it work
# Out:
# 3
